# %%
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %%
img=cv2.imread('thala.jpg')
img2=img[:,:,::-1] #another way to create rgb to bgr

plt.imshow(img2)

# %%
image=Image.open('thala.jpg')

# %%
from PIL import ExifTags
im = Image.open('thala.jpg')
exif = im.getexif()
gps_ifd = exif.get_ifd(ExifTags.IFD.GPSInfo)
print(gps_ifd)
# Out:
# {}

# %%
for tag,value in image.getexif():
    print(tag,value)

# %%
import PIL.ExifTags
from PIL import Image
def read_exif_data(image_path):
    image = Image.open(image_path)
    exif_data = image._getexif()
    
    if exif_data is not None:
        for tag, value in exif_data.items():
            tag_name = PIL.ExifTags.TAGS.get(tag, tag)
            print(f"{tag_name}: {value}")
    else:
        print("No Exif data found.")

# %%
read_exif_data('thala.jpg')
# Out:
# No Exif data found.
